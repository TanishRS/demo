# %%
import numpy as np
product = np.array([100,200,300,400,150,250,350,450,1890])
print(product)
# Out:
# [ 100  200  300  400  150  250  350  450 1890]

# %%
discounted_prices = np.where(
    product < 300, product * 0.95,
    np.where(product <= 1000, product * 0.90, product * 0.85)
)

print(discounted_prices)
# Out:
# [  95.   190.   270.   360.   142.5  237.5  315.   405.  1606.5]
