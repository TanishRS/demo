# %%
import numpy as np
age=np.random.normal(18,35,15)
print(age)
# Out:
# [ 23.21077422  14.52768613 -18.18275934  15.98103582  34.44696597
#   30.52690232  31.79213445 -11.96506747 -18.62356592 -43.35449538
#   23.69845267  60.62788316  38.24676388  23.41005404  28.08454389]

# %%
purchase=np.random.uniform(18,35,15)
print(purchase)
# Out:
# [20.24398085 34.72863291 27.0107087  33.51339855 23.03227114 20.28283506
#  20.82570357 33.23495577 29.81419405 26.64671617 18.31799808 19.16970806
#  20.23243704 19.44582243 29.84195044]

# %%
import numpy as np
ran_choice=np.random.choice(age,10,5)
print(ran_choice)
# Out:
# [ 31.79213445  23.69845267 -11.96506747  34.44696597  38.24676388
#   23.69845267  30.52690232 -18.18275934  15.98103582  23.21077422]

# %%
import numpy as np

# %%
dice=np.random.randint(1,7,1000)
total_outcomes=np.bincount(dice)[1]
print(total_outcomes)
# Out:
# 163
