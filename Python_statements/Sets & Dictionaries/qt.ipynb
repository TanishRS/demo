# %%
users = {
    "username" : "Ved",
    "age" : 24,
    "is_admin" : True

}
print(users)
# Out:
# {'username': 'Ved', 'age': 24, 'is_admin': True}

# %%
print(users.get("username"));print(users.get("age"));print(users.get("is_admin"))
# Out:
# Ved
# 24
# True

# %%
users.pop("is_admin")
# Out:
# True

# %%
print(users)
# Out:
# {'username': 'Ved', 'age': 24}

# %%
users.update({"is_admin" : True})

# %%
print(users)
# Out:
# {'username': 'Ved', 'age': 24, 'is_admin': True}

# %%
del users["is_admin"]
print(users)
# Out:
# {'username': 'Ved', 'age': 24}

# %%
del users

# %%
users = {
    "username" : "Ved",
    "age" : 24,
    "is_admin" : True

}

# %%
print(len(users))
# Out:
# 3

# %%
for x in users:
    print(x)
# Out:
# username
# age
# is_admin

# %%
for x in users:
    print(users[x])
# Out:
# Ved
# 24
# True

# %%
import numpy
